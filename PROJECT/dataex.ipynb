# %%
import pandas as pd

# %%
df1=pd.read_csv('C:\Codding\Data Science\PROJECT\StudentPerformanceFactors.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\POOJA\AppData\Local\Temp\ipykernel_24500\3070102151.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df1=pd.read_csv('C:\Codding\Data Science\PROJECT\StudentPerformanceFactors.csv')

# %%
df1
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df2=pd.read_csv('C:\Codding\Data Science\PROJECT\Coursera.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\POOJA\AppData\Local\Temp\ipykernel_24500\3195005912.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df2=pd.read_csv('C:\Codding\Data Science\PROJECT\Coursera.csv')

# %%
df2
# Out:
#                                             Course Name  \
# 0     Write A Feature Length Screenplay For Film Or ...
# 1     Business Strategy: Business Model Canvas Analy...
# 2                         Silicon Thin Film Solar Cells
# 3                                  Finance for Managers
# 4          Retrieve Data using Single-Table SQL Queries
# ...                                                 ...
# 3517  Capstone: Retrieving, Processing, and Visualiz...
# 3518                   Patrick Henry: Forgotten Founder
# 3519  Business intelligence and data analytics: Gene...
# 3520                                Rigid Body Dynamics
# 3521  Architecting with Google Kubernetes Engine: Pr...
#
#                                              University Difficulty Level  \
# 0                             Michigan State University         Beginner
# 1                              Coursera Project Network         Beginner
# ...

# %%
df1.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Course Name', 'University', 'Difficulty Level', 'Course Rating',
#        'Course URL', 'Course Description', 'Skills'],
#       dtype='object')

# %%
df11=df1[['Previous_Scores','Family_Income','Parental_Education_Level','Exam_Score','Extracurricular_Activities']]

# %%
df22=df2[['Course Name', 'University', 'Difficulty Level', 'Course Rating', 'Course Description', 'Skills']]

# %%
df=pd.concat([df22, df11], axis=1)

# %%
df
# Out:
#                                             Course Name  \
# 0     Write A Feature Length Screenplay For Film Or ...
# 1     Business Strategy: Business Model Canvas Analy...
# 2                         Silicon Thin Film Solar Cells
# 3                                  Finance for Managers
# 4          Retrieve Data using Single-Table SQL Queries
# ...                                                 ...
# 6602                                                NaN
# 6603                                                NaN
# 6604                                                NaN
# 6605                                                NaN
# 6606                                                NaN
#
#                      University Difficulty Level Course Rating  \
# 0     Michigan State University         Beginner           4.8
# 1      Coursera Project Network         Beginner           4.8
# 2           �cole Polytechnique         Advanced           4.1
# ...

# %%
df=df.rename(columns={'Exam_Score':'Applitude'})

# %%
df
# Out:
#                                             Course Name  \
# 0     Write A Feature Length Screenplay For Film Or ...
# 1     Business Strategy: Business Model Canvas Analy...
# 2                         Silicon Thin Film Solar Cells
# 3                                  Finance for Managers
# 4          Retrieve Data using Single-Table SQL Queries
# ...                                                 ...
# 6602                                                NaN
# 6603                                                NaN
# 6604                                                NaN
# 6605                                                NaN
# 6606                                                NaN
#
#                      University Difficulty Level Course Rating  \
# 0     Michigan State University         Beginner           4.8
# 1      Coursera Project Network         Beginner           4.8
# 2           �cole Polytechnique         Advanced           4.1
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('C:\Codding\Data Science\PROJECT\Data_ML_project.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\POOJA\AppData\Local\Temp\ipykernel_21224\2984551966.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df=pd.read_csv('C:\Codding\Data Science\PROJECT\Data_ML_project.csv')

# %%
df
# Out:
#                                             Course Name  \
# 0                Acing the Product Management Interview
# 1                  The Business of Product Management I
# 2               The Art & Science of Product Management
# 3     Machine Learning Algorithms: Supervised Learni...
# 4                             Data for Machine Learning
# ...                                                 ...
# 3448                      Understanding Korean Politics
# 3449  International Marketing & Cross Industry Growt...
# 3450  Gender, Family, and Social Change in Contempor...
# 3451                         Deep Learning for Business
# 3452                   Re-imaging God in Korean Context
#
#                                   University Aptitude Score Family_Income  \
# 0                 Advancing Women in Product             71          High
# 1                 Advancing Women in Product             75           Low
# ...
