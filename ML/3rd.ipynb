# %% [markdown]
# ## SMOTE(Synthetic Minority Oversampling Technique)
# SMOTE (Synthetic Minority Over-sampling Technique) is a technique used in machine learning to address imbalanced datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# x independent feature
#
# y dependent feature

# %%
x,y=make_classification(n_samples=1000,n_features=2,n_clusters_per_class=1,weights=[0.90],random_state=1,n_redundant=0)

# %%
df1=pd.DataFrame(x,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
final_df=pd.concat([df1,df2],axis=1)

# %%
final_df.head()
# Out:
#          f1        f2  target
# 0  1.536830 -1.398694       1
# 1  1.551108  1.810329       0
# 2  1.293619  1.010946       0
# 3  1.119889  1.632518       0
# 4  1.042356  1.121529       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    894
# 1    106
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
from imblearn.over_sampling import SMOTE

# %%
#tansform the dataset
oversample = SMOTE()
x,y=oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
x.shape
# Out:
# (1788, 2)

# %%
y.shape
# Out:
# (1788,)

# %%
len(y[y==0])
# Out:
# 894

# %%
len(y[y==1])
# Out:
# 894

# %%
df1=pd.DataFrame(x,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
oversample_df=pd.concat([df1,df2],axis=1)

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['target'])

# %%
a,b=make_classification(n_samples=5000,n_features=3,n_clusters_per_class=1,weights=[0.80],n_redundant=0)

# %%
dfa=pd.DataFrame(a,columns=['f1','f2','f3'])
dfb=pd.DataFrame(b,columns=['target'])
final_d=pd.concat([dfa,dfb],axis=1)

# %%
final_d.head()
# Out:
#          f1        f2        f3  target
# 0 -0.895848  0.564904  0.720845       0
# 1 -1.195423  1.150403  0.908059       0
# 2  0.239899  0.593013  0.701902       0
# 3  1.746199  1.191816  1.427335       0
# 4 -0.570043  1.008545  0.980931       0

# %%
final_d['target'].value_counts()
# Out:
# target
# 0    3988
# 1    1012
# Name: count, dtype: int64

# %%
plt.scatter(final_d['f1'],final_d['f2'],final_d['f3'],c=final_d['target'])
# Out:
# C:\Users\POOJA\AppData\Roaming\Python\Python312\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
a,b=oversample.fit_resample(final_d[['f1','f2','f3']],final_d['target'])

# %%
a.shape
# Out:
# (7976, 3)

# %%
b.shape
# Out:
# (7976,)

# %%
len(b[b==0])
# Out:
# 3988

# %%
len(b[b==1])
# Out:
# 3988

# %%
dfa=pd.DataFrame(a,columns=['f1','f2','f3'])
dfb=pd.DataFrame(b,columns=['target'])
oversample_d=pd.concat([dfa,dfb],axis=1)

# %%
plt.scatter(oversample_d['f1'],oversample_d['f2'],oversample_d['f3'],oversample_d['target'])
# Out:
# C:\Users\POOJA\AppData\Roaming\Python\Python312\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
